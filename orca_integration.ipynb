# %% [markdown]
# # Orca Implementation and Overlay of spectra

# %%
import spec_tools

# %%
orca_data = spec_tools.spectrum.Spectrum.from_orca_spectrum(filepath="tests/orca_tests/acetic_acid.out.ir.dat")

# %%
orca_data.plot_spectrum()
# Out:
# alt.Chart(...)
